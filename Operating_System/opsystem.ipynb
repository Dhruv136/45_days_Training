# %% [markdown]
# The os module is used to interact with the operating system. It helps you work with files, folders, directories, and system-related tasks.

# %%
import os

# %%
import os
print(os.getcwd()) # gives current working directory
# Out:
# c:\Users\kokch\internship\Operating_System

# %%
os.listdir(r'C:\Users\kokch\OneDrive\Pictures') # list the foldeer in specfied path
# Out:
# ['Camera Roll', 'desktop.ini', 'lenovo.jpg', 'Screenshots']

# %%
os.listdir() # list the item in current folder
# Out:
# ['opsystem.ipynb']

# %%
os.mkdir("folder made by mkdir") # make a new folder

# %%
import os
#to rename file  change file name by new name 
os.rename("new.txt","old.txt")

print("File Renamed")

# %%
import os
# os.chdir(r"C:\Games\Chained Together\ChainedTogether")
print(os.getcwd())
# Out:
# C:\Games\Chained Together\ChainedTogether

# %%
import os 
path=r"C:\Games\Chained Together\ChainedTogether"
os.path.isdir(path)
# Out:
# True
