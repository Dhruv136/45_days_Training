# %%
a=int(input("Enter a number bro "))
print("the square of number is ",a*a)
# Out:
# the square of number is  16

# %%
a = 10
b=10
print("addition:", a+b)
print("subtraction:",a-b)
print("multiplication:",a*b)
print("divison:",a/b)
print("floor divison:",a//b)
print(a**b)
print(a%b)
# Out:
# addition: 20
# subtraction: 0
# multiplication: 100
# divison: 1.0
# floor divison: 1
# 10000000000
# 0

# %%
text = "bruh"
reversed_text = text[::-1]
print(reversed_text)
# Out:
# hurb

# %%
lst = [1, 2, 3, 4, 5]

for num in lst:
    if num % 2 == 0:
        print(num)
# Out:
# 2
# 4

# %%
student = {"name": "Dhruv", "age": 20}
student["age"] = 21
print(student)
# Out:
# {'name': 'Dhruv', 'age': 21}
