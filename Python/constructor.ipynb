# %%
# constructor 

class College:
    def __init__(self): # it is the default name for comnstructor used for inititlizations
        pass
st=College()

# %%
class College:
    college_name="bkbiet" #class variable
    def __init__(self):
        self.name="dhruv" #instance variable
        self.classes="second year"
st=College()

# %%
st.name
# Out:
# 'dhruv'

# %%
st.classes
# Out:
# 'second year'

# %%
#parameterized constructor
class College:
    college_name="bkbiet" #class variable
    def __init__(self,name,classes):
        self.name= name #instance variable
        self.classes= classes
st=College(name="dhruv",classes="second year")

# %%
st.classes
# Out:
# 'second year'

# %%
st.name
# Out:
# 'dhruv'

# %%
#using consntructor variable in a function 
class College:
    college_name="bkbiet" #class variable
    def __init__(self,name,classes):
        self.name=name #instance variable
        self.classes=classes
    def account(self):
        print(f"my name is {self.name} and my class is {self.classes}")   
st=College(name="dhruv",classes="csa")

# %%
st.account()
# Out:
# my name is dhruv and my class is csa

# %%
class Vehicles:
    def __init__(self):
        self.type="cars"
        self.type1="bike"
class Bike(Vehicles):
    def __init__(self):
        super().__init__()
        self.name1="honda"
        self.no1="rj18"
class Car(Bike):             
    def __init__(self):
        super().__init__()
        self.name2="maruti"
        self.no2="rj24"
ca=Car()

# %%
ca.name1
# Out:
# 'honda'

# %%
ca.name2
# Out:
# 'maruti'

# %%
ca.no1
# Out:
# 'rj18'

# %%
ca.no2
# Out:
# 'rj24'

# %%
#what happens when we use multiple constructor in python
class Student:
    def __init__(self):
        print("First constructor")

    def __init__(self, name):
        print("Second constructor")

s = Student("Dhruv")
# Out:
# Second constructor

# %%
class Store:
    def __init__(self, Store_Id, Store_Name, Location):
        self.Store_Id = Store_Id
        self.Store_Name = Store_Name
        self.Location = Location
class Product(Store):
    def __init__(self, Store_Id, Store_Name, Location,
                 P_Id, P_Name, Price):
        super().__init__(Store_Id, Store_Name, Location)
        self.P_Id = P_Id
        self.P_Name = P_Name
        self.Price = Price
    def Disp(self):
        print("Store ID:", self.Store_Id)
        print("Store Name:", self.Store_Name)
        print("Location:", self.Location)
        print("Product ID:", self.P_Id)
        print("Product Name:", self.P_Name)
        print("Price:", self.Price)
class Employ(Store):
    def __init__(self, Store_Id, Store_Name, Location,
                 E_Id, E_Name, Salary):
        super().__init__(Store_Id, Store_Name, Location)
        self.__E_Id = E_Id
        self.E_Name = E_Name
        self.__Salary = Salary
    def Disp(self):
        print("Store ID:", self.Store_Id)
        print("Store Name:", self.Store_Name)
        print("Location:", self.Location)
        print("Employee ID:", self.__E_Id)
        print("Employee Name:", self.E_Name)
        print("Employee Salary:", self.__Salary)
E1 = Employ(101, "Reliance Mart", "Delhi",501, "Rahul", 35000)
P1 = Product(101, "Reliance Mart", "Delhi",1001, "Laptop", 55000)
print("Detail of E1 Employ:")
E1.Disp()
print()
print("Detail of P1 Product:")
P1.Disp()
# Out:
# Detail of E1 Employ:
# Store ID: 101
# Store Name: Reliance Mart
# Location: Delhi
# Employee ID: 501
# Employee Name: Rahul
# Employee Salary: 35000
#
# Detail of P1 Product:
# Store ID: 101
# Store Name: Reliance Mart
# Location: Delhi
# Product ID: 1001
# Product Name: Laptop
# Price: 55000

# %%
# Polymorphism
class Bird:
    def sound(self):
        print("Chirp")
class Dog:
    def sound(self):
        print("Bark")
obj1 = Bird()
obj2 = Dog()
obj1.sound()
obj2.sound()
# Out:
# Chirp
# Bark
