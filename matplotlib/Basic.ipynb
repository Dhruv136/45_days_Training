# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,4]
y=[10,20,30,40]
plt.plot(x,y)

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\kokch\45_days_Training\Pandas\Titanic_test.csv")

plt.plot(df["Age"], df["Fare"],"g",marker="*")
plt.show()

# %%
plt.bar(df["Age"], df["Fare"])
# Out:
# <BarContainer object of 418 artists>
